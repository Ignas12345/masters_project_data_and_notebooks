# %%
import sys
# !git clone https://github.com/Ignas12345/masters_project_helper_functions.git
sys.path.append('/content/masters_project_helper_functions')
# Out:
# Cloning into 'masters_project_helper_functions'...
# remote: Enumerating objects: 95, done.
# remote: Counting objects: 100% (95/95), done.
# remote: Compressing objects: 100% (68/68), done.
# remote: Total 95 (delta 48), reused 64 (delta 24), pack-reused 0 (from 0)
# Receiving objects: 100% (95/95), 39.34 KiB | 3.28 MiB/s, done.
# Resolving deltas: 100% (48/48), done.

# %%
import pandas as pd
import numpy as np

import masters_project_helper_functions.utils as utils
import masters_project_helper_functions.bootstrap_fold_preparation as bootstrap_fold_preparation

# %%
sample_label_dict = pd.read_csv('https://raw.githubusercontent.com/Ignas12345/masters_project_data_and_notebooks/refs/heads/main/Data/sample_annotations/TGCT_vs_non_TGCT_labels.csv', sep = ';', index_col=0)['label'].to_dict()

# %%
experiment_name = 'TGCT_vs_non_TGCT'
train_folds_df, test_folds_df, info_df = bootstrap_fold_preparation.prepare_folds_for_experiment(sample_label_dict, experiment_name)
train_folds_df.to_csv(f'train_folds_{experiment_name}.csv')
test_folds_df.to_csv(f'test_folds_{experiment_name}.csv')
info_df.to_csv(f'info_df_{experiment_name}.csv')
# Out:
# preparing folds for: TGCT_vs_non_TGCT
# 0
# 0
# 0
# 0

# %%
train_folds_df
# Out:
#                                                 samples proportion TGCT  \
# 0     Index(['TCGA-2G-AAEW-01', 'TCGA-2G-AAEX-01', '...        0.270217
# 1     [TCGA-2G-AAEX-01, TCGA-2G-AAF1-01, TCGA-2G-AAF...        0.268775
# 2     [TCGA-2G-AAEW-01, TCGA-2G-AAF1-01, TCGA-2G-AAF...        0.268775
# 3     [TCGA-2G-AAEW-01, TCGA-2G-AAEX-01, TCGA-2G-AAF...        0.268775
# 4     [TCGA-2G-AAEW-01, TCGA-2G-AAEX-01, TCGA-2G-AAF...        0.268775
# ...                                                 ...             ...
# 2503  [TCGA-2G-AAH4-01, TCGA-DJ-A2PQ-01, TCGA-2G-AAG...        0.483235
# 2504  [TCGA-YU-A94D-01, TCGA-WZ-A8D5-01, TCGA-S6-A8J...        0.487179
# 2505  [TCGA-D3-A2JK-06, TCGA-SN-A6IS-01, TCGA-2G-AAG...        0.469428
# 2506  [TCGA-P5-A72X-01, TCGA-CC-5263-01, TCGA-2G-AAH...        0.487179
# 2507  [GTEX-1KWVE-1126-SM-G6EG8, GTEX-1JKYN-1026-SM-...        0.546351
#
#      proportion non_TGCT train_fold_length                   comment
# 0               0.729783               507      all training samples
# 1               0.731225               506                loocv fold
# 2               0.731225               506                loocv fold
# 3               0.731225               506                loocv fold
# 4               0.731225               506                loocv fold
# ...                  ...               ...                       ...
# 2503            0.516765               507  stratifed bootstrap fold
# 2504            0.512821               507  stratifed bootstrap fold
# 2505            0.530572               507  stratifed bootstrap fold
# 2506            0.512821               507  stratifed bootstrap fold
# 2507            0.453649               507  stratifed bootstrap fold
#
# [2508 rows x 5 columns]
